# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=18,random_state=13)

# %%
sns.scatterplot(x=x.flatten(),y=y)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
r=LinearRegression()
r.fit(x,y)
# Out:
# LinearRegression()

# %%
r.intercept_
# Out:
# 5.885917389704843

# %%
r.coef_
# Out:
# array([64.82968412])

# %%
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x))
# Out:
# <Axes: >

# %%
# gradient decent
m=64.82968412
b=0

# %%
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 0

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.650480693780772

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.838830050240132

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.8764999215320035

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.8840338957903775

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.885540690642053

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.885842049612387

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
b=b-(0.1)*slope
y_predict=((64.82968412*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
print(b)
# Out:
# 5.885902321406454

# %%
b=5.885917389704843
m=0
slope = (-2)*sum(y-(m*x.ravel())-b)
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
slope = (-2)*sum(y-(m*x.ravel())-b)
m=m-(0.1)*slope
y_predict=((m*x)+b).reshape(4)
sns.scatterplot(x=x.flatten(),y=y)
sns.lineplot(x=x.flatten(),y=r.predict(x),color="green")
sns.lineplot(x=x.flatten(),y=y_predict,color="red")
# Out:
# <Axes: >

# %%
m
# Out:
# 64.46159499777663
