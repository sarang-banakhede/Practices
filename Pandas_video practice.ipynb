# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\saran\\OneDrive\\Desktop\\Workspace\\train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[1:3] #access by rows
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df["Ticket"] # acess by column
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df[['Ticket','Fare']] #access by multiple columns
# Out:
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 2 columns]

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index].head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
df[df.dtypes[df.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df[["Ticket"]][1:5]
# Out:
#              Ticket
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %%
df["new_col"]=0 #add new column
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["age+Pclass"]=df["Age"]+df["Pclass"] #add new column with sum of two columns
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df["Pclass"].unique() #unique values in a column
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df["PassengerId"][1:6][df["Age"]>20] #access by rows and columns with condition 
#df[[columns]][row start : row end + 1][condition]
# Out:
# 1    2
# 2    3
# 3    4
# 4    5
# Name: PassengerId, dtype: int64

# %%
#selecting rows and columns 
#df.iloc[row start : row end + 1, column start : column end + 1] ACESS BY INDEX
#df.loc[row start : row end + 1, column start : column end + 1] ACESS BY LABEL
#df.loc[row start : row end + 1, [list of column]] ACESS BY LABEL

# %%
s=df['Name'][0:10]

# %%
s.index=['a','b','c','d','e','f','g','h','i','j']

# %%
s
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
s[0] #access by index
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s['a'] #access by label
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s.append(pd.Series(["sarang"],index=['h']))
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\2350228253.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(pd.Series(["sarang"],index=['h']))
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# h                                               sarang
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col',
#        'age+Pclass'],
#       dtype='object')

# %%
s=df["Name"][0:10]

# %%
s.index=['a','b','c','d','e','f','g','h','i','j']
s
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
list(s.items())
# Out:
# [('a', 'Braund, Mr. Owen Harris'),
#  ('b', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'),
#  ('c', 'Heikkinen, Miss. Laina'),
#  ('d', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'),
#  ('e', 'Allen, Mr. William Henry'),
#  ('f', 'Moran, Mr. James'),
#  ('g', 'McCarthy, Mr. Timothy J'),
#  ('h', 'Palsson, Master. Gosta Leonard'),
#  ('i', 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'),
#  ('j', 'Nasser, Mrs. Nicholas (Adele Achem)')]

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'new_col',
#        'age+Pclass'],
#       dtype='object')

# %%
df.drop("PassengerId",axis=1,inplace=True) #drop column

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.drop(2,axis=0,inplace=True) #drop row

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
df.set_index("Name",inplace=True) #set index

# %%
df.reset_index(inplace= True) #reset index

# %%
d={'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]}
pd.DataFrame(d)
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.dropna()
# Out:
#                                                   Name  Survived  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 5                              McCarthy, Mr. Timothy J         0       1
# 9                      Sandstrom, Miss. Marguerite Rut         1       3
# 10                            Bonnell, Miss. Elizabeth         1       1
# ..                                                 ...       ...     ...
# 870   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1       1
# 871                           Carlsson, Mr. Frans Olof         0       1
# 878      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 886                       Graham, Miss. Margaret Edith         1       1
# 888                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  new_col  \
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S        0
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C        0
# 2  female  35.0      1      0     113803  53.1000  C123        S        0
# 3    male  35.0      0      0     373450   8.0500   NaN        S        0
# 4    male   NaN      0      0     330877   8.4583   NaN        Q        0
#
#    age+Pclass
# 0        25.0
# 1        39.0
# 2        36.0
# 3        38.0
# 4         NaN

# %%
g=df.groupby("Survived")

# %%
g.sum()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare  new_col  age+Pclass
# Survived
# 0           1390  12985.50    304    181  12142.7199        0    14039.50
# 1            664   8193.67    162    159  16543.3044        0     8733.67

# %%
g.mean()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare  new_col  \
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887      0.0
# 1         1.947214  28.351799  0.475073  0.466276  48.514089      0.0
#
#           age+Pclass
# Survived
# 0          33.112028
# 1          30.220311

# %%
g1=df.groupby("Pclass")

# %%
g1.sum()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare  new_col  age+Pclass
# Pclass
# 1            136  7111.42     90     77  18177.4125        0     7297.42
# 2             87  5168.83     74     70   3801.8417        0     5514.83
# 3            118  8898.92    302    193   6706.7701        0     9960.92

# %%
g1.mean()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare  new_col  \
# Pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687      0.0
# 2       0.472826  29.877630  0.402174  0.380435  20.662183      0.0
# 3       0.240816  25.138192  0.616327  0.393878  13.687286      0.0
#
#         age+Pclass
# Pclass
# 1        39.233441
# 2        31.877630
# 3        28.138192

# %%
g1.max().T
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                             1                          2  \
# Name        Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                           1                          1
# Sex                             male                       male
# Age                             80.0                       70.0
# SibSp                              3                          3
# Parch                              4                          3
# Ticket                     WE/P 5735                  W/C 14208
# Fare                        512.3292                       73.5
# new_col                            0                          0
# ...

# %%
df2=df[['Name','Survived','Pclass']][0:5]
df3=df[['Name','Survived','Pclass']][5:10]

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4.fillna("sarang")
# Out:
#                                                 Name Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0     1.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0     1.0
# 3                           Allen, Mr. William Henry      0.0     3.0
# 4                                   Moran, Mr. James      0.0     3.0
# 5                                             sarang   sarang  sarang
# 6                                             sarang   sarang  sarang
# 7                                             sarang   sarang  sarang
# 8                                             sarang   sarang  sarang
# 9                                             sarang   sarang  sarang
#
#                                                 Name Survived  Pclass
# 0                                             sarang   sarang  sarang
# ...

# %%
data=pd.DataFrame({'Key':['K0','K1','K2','K3','K4','K5'],'A':['A0','A1','A2','A3','A4','A5'],'B':['B0','B1','B2','B3','B4','B5']})

# %%
data.T
# Out:
#       0   1   2   3   4   5
# Key  K0  K1  K2  K3  K4  K5
# A    A0  A1  A2  A3  A4  A5
# B    B0  B1  B2  B3  B4  B5

# %%
data2=pd.DataFrame({'Key':['K0','K1','K2','K7','K8','K9'],'C':['C0','C1','C2','C3','C4','C5'],'D':['D0','D1','D2','D3','D4','D5']}])

# %%
pd.merge(data,data2)
# Out:
#   Key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2

# %%
pd.merge(data,data2,how='left')
# Out:
#   Key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K1  A1  B1   C1   D1
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3  NaN  NaN
# 4  K4  A4  B4  NaN  NaN
# 5  K5  A5  B5  NaN  NaN

# %%
data2=pd.DataFrame({'Key1':['K0','K1','K2','K7','K8','K9'],'C':['C0','C1','C2','C3','C4','C5'],'D':['D0','D1','D2','D3','D4','D5']},index=['a','b','c','d','e','f'])
data3=pd.DataFrame({'Key':['K0','K1','K2','K3','K4','K5'],'A':['A0','A1','A2','A3','A4','A5'],'B':['B0','B1','B2','B3','B4','B5']},index=['a','b','g','d','i','j'])

# %%
data2.join(data3,how='left')
# Out:
#   Key1   C   D  Key    A    B
# a   K0  C0  D0   K0   A0   B0
# b   K1  C1  D1   K1   A1   B1
# c   K2  C2  D2  NaN  NaN  NaN
# d   K7  C3  D3   K3   A3   B3
# e   K8  C4  D4  NaN  NaN  NaN
# f   K9  C5  D5  NaN  NaN  NaN

# %%
data2.join(data3)
# Out:
#   Key1   C   D  Key    A    B
# a   K0  C0  D0   K0   A0   B0
# b   K1  C1  D1   K1   A1   B1
# c   K2  C2  D2  NaN  NaN  NaN
# d   K7  C3  D3   K3   A3   B3
# e   K8  C4  D4  NaN  NaN  NaN
# f   K9  C5  D5  NaN  NaN  NaN

# %%
df['INR']=df['Fare'].apply(lambda x:x*80)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
for i in range(890):
    if df["Fare"][i]<10:
        df["Fare"][i]="cheap"
    elif df["Fare"][i]<30:
        df["Fare"][i]="moderate"
    else:
        df["Fare"][i]="expensive"
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_13296\266254776.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fare"][i]="cheap"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
data2=pd.DataFrame({'Key':['K0','K1','K2','K7','K8','K9'],'C':['C0','C1','C2','C3','C4','C5'],'D':['D0','D1','D2','D3','D4','D5']})

# %%
data2
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K7  C3  D3
# 4  K8  C4  D4
# 5  K9  C5  D5

# %%
data2.set_index('Key')
# Out:
#       C   D
# Key
# K0   C0  D0
# K1   C1  D1
# K2   C2  D2
# K7   C3  D3
# K8   C4  D4
# K9   C5  D5

# %%
for i in data2.iteritems():
    print(i)
# Out:
# ('Key', 0    K0
# 1    K1
# 2    K2
# 3    K7
# 4    K8
# 5    K9
# Name: Key, dtype: object)
# ('C', 0    C0
# 1    C1
# 2    C2
# 3    C3
# 4    C4
# 5    C5
# Name: C, dtype: object)
# ('D', 0    D0
# 1    D1
# 2    D2
# 3    D3
# 4    D4
# 5    D5
# Name: D, dtype: object)
# C:\Users\saran\AppData\Local\Temp\ipykernel_9312\3769988552.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in data2.iteritems():

# %%
[i for i in data2.C]
# Out:
# ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']

# %%
data2
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K7  C3  D3
# 4  K8  C4  D4
# 5  K9  C5  D5

# %%
def test(x):
    return x.sum()
data2.apply(test)
# Out:
# Key    K0K1K2K7K8K9
# C      C0C1C2C3C4C5
# D      D0D1D2D3D4D5
# dtype: object
